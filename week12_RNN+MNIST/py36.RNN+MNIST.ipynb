# %% [markdown]
# # 0.1 라이브러리 임포트

# %%
import torch
import torch.nn as nn
import torchvision.datasets as dset
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.autograd import Variable

# %% [markdown]
# # 0.2 하이퍼파라미터 셋팅

# %%
# Hyper-parameters - 학습 할 때 튜닝의 대상
sequence_length=28
input_size=28
hidden_size=128
num_layers=2

num_classes=10
batch_size=100
num_epochs=7
learning_rate=0.01

# %%
# Device configuration
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # 1. MNIST train, test dataset 가져오기

# %%
#"": 현재 폴더에 MNIST 있음
mnist_train=dset.MNIST("",train=True,transform=transforms.ToTensor(),
                       target_transform=None, download=True) ##Train용
mnist_test=dset.MNIST("",train=False, transform=transforms.ToTensor(),
                      target_transform=None,download=True) ##Test용

# %% [markdown]
# # 2. 대략적인 데이터 형태

# %%
print ("mnist_train 길이:", len(mnist_train))
print ("mnist_test 길이:", len(mnist_test))

#데이터 하나 형태
image, label=mnist_train.__getitem__(1515)
print ("image data 형태:", image.size()) # 1, 28, 28 # channel, w, h
print ("label: ", label)

#그리기
img=image.numpy() #image 타입을 numpy로 변환(1,28,28)
plt.title("label: %d" %label)
plt.imshow(img[0],cmap='gray')
plt.show()
# Out:
# mnist_train 길이: 60000
# mnist_test 길이: 10000
# image data 형태: torch.Size([1, 28, 28])
# label:  6

# %% [markdown]
# # 3. 데이터 로드함수

# %%
train_loader=torch.utils.data.DataLoader(dataset=mnist_train,
                                         batch_size=batch_size, # mnist_train을 트레인
                                         shuffle=True,
                                         drop_last=True) #batch_size 만큼 나눌 때 나머지는 버려라 
test_loader=torch.utils.data.DataLoader(dataset=mnist_test,
                                        batch_size=batch_size,
                                        shuffle=False, #보통 test는 suhffle하지 않는다.
                                        drop_last=True)

# %% [markdown]
# # 데이터 로드함수 이해하기

# %%
n=3 # 샘플로 그려볼 데이터 개수
for i, [imgs, labels] in enumerate(test_loader): #batch_size 만큼
    if i>5:
        break
    print ("[%d]" %i)
    print ("한 번에 로드되는 데이터 크기: ", len(imgs))
    
    #그리기
    for j in range(n):
        img=imgs[j].numpy() #image 타입을 numpy로 변환(1,28,28)
        img=img.reshape((img.shape[1],img.shape[2])) #(1,28,28)->(28,28)
        
        #print img.shape
        plt.subplot(1,n,j+1) #(1,3) 형태 플랏의 j번째 자리에 그리겠다.
        plt.imshow(img, cmap='gray')
        plt.title("label: %d" %labels[j])
    plt.show()
# Out:
# [0]
# 한 번에 로드되는 데이터 크기:  100
# [1]
# 한 번에 로드되는 데이터 크기:  100
# [2]
# 한 번에 로드되는 데이터 크기:  100
# [3]
# 한 번에 로드되는 데이터 크기:  100
# [4]
# 한 번에 로드되는 데이터 크기:  100
# [5]
# 한 번에 로드되는 데이터 크기:  100

# %% [markdown]
# # 4. 모델 선언

# %%
# Recurrent neural network (many-to-one)
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes): # 순서가바뀌어도 상관없다. 아래서만 잘 쓰면됨 / 순서대로 쓰는게 보통!
        super(RNN, self).__init__()
        self.hidden_size = hidden_size #128
        self.num_layers = num_layers # 2
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, num_classes) #128-10
        
    def forward(self, x):
        # -----------------
        # input tensor: (batch_size, seq_length, input_size) # bs, n, vector size
        # x: (100,28,28)
        # print('x: ', x.shape)
        
        # -----------------
        # hidden state tensor: (# of layers, batch_size, hidden_size)
        # h: (2, 100, 128)
        
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device) # 0값으로 초기화, size는 #layers, x.size(0)=batch_size
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        
        # -----------------
        # Forward propagate LSTM
        # output tensor: (batch_size, seq_length, hidden_size)
        # out:(128,28,128)
        # print('out',out.shape)
        
        out, _ = self.lstm(x, (h0, c0))
        
        # -----------------
        # 28번째 output layer: (bs, hidden_size) (마지막것만 사용)
        # out[:,-1,:]: (100,128)
        # print('out[-1]:',out[:,-1,:].shape) # batchsize 다가져옴/-1: 마지막 index만 가져옴/hidden_size 다가져옴
        
        # -----------------
        out = self.fc(out[:, -1, :])
        
        # y^: (batch_size,num_classes)
        # y_pred:(100,10)
        # print('out: ',out.shape)
        
        return out

# %%
model=RNN(input_size,hidden_size,num_layers,num_classes).to(device)

# %%
def ComputeAccr(dloader, imodel):
    correct=0
    total=0
    
    for j, [imgs,labels] in enumerate(dloader): #batch_size 만큼
        # x: (batch_size, 1, seq_length, input_size) ->(batch_size, seq_length, input_size)
        img=imgs
        img=img.reshape(-1,sequence_length,input_size).to(device)
        
        # y: (batch_size, num_classes)
        label=labels.to(device) # y # Variable(labels)
        #label=Variable(labels).cuda()
        #.cuda(): GPU에 로드되기 위함, 만약 CPU로 설정되어 있다면 에러남
        
        # Forward prop.
        output=imodel(img) #(batch_size, num_classes)
        _, output_index=torch.max(output,1) # (batch_size, 1)
        
        total+=label.size(0)
        correct+=(output_index==label).sum().float()
        
    return (100*correct/total).cpu().numpy() # tensor -> numpy # gpu에서실행시 .cpu() 해줘야지 numpy로 바뀜

# %%
print("Accuracy of Test Data: %.2f" %ComputeAccr(test_loader, model))
# Out:
# Accuracy of Test Data: 8.76

# %% [markdown]
# # 5. loss, optimizer

# %%
# Loss and optimizer
loss_func=nn.CrossEntropyLoss()
optimizer=torch.optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# # 6. 학습

# %%
# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, [imgs, labels] in enumerate(train_loader):
        # x: (batch_size, 1, seq_length, input_size) ->(batch_size, seq_length, input_size)
        img=imgs
        img=img.reshape(-1,sequence_length,input_size).to(device)
        
        # y: (batch_size, num_classes)
        label=labels.to(device) # y # Variable(labels)
        
        # Forward pass
        outputs = model(img)
        loss = loss_func(outputs, label)
        
        # Backward prop.& optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accr:{:.2f}' 
                   .format(epoch+1, num_epochs, i+1, total_step,
                           loss.item(),
                           ComputeAccr(test_loader,model)))
# Out:
# Epoch [1/7], Step [100/600], Loss: 0.3671, Accr:76.63
# Epoch [1/7], Step [200/600], Loss: 0.1443, Accr:92.99
# Epoch [1/7], Step [300/600], Loss: 0.1662, Accr:94.25
# Epoch [1/7], Step [400/600], Loss: 0.1702, Accr:95.45
# Epoch [1/7], Step [500/600], Loss: 0.1166, Accr:96.50
# Epoch [1/7], Step [600/600], Loss: 0.1870, Accr:97.29
# Epoch [2/7], Step [100/600], Loss: 0.2211, Accr:96.32
# Epoch [2/7], Step [200/600], Loss: 0.1870, Accr:97.47
# Epoch [2/7], Step [300/600], Loss: 0.2023, Accr:97.43
# Epoch [2/7], Step [400/600], Loss: 0.0878, Accr:97.51
# Epoch [2/7], Step [500/600], Loss: 0.0318, Accr:97.36
# Epoch [2/7], Step [600/600], Loss: 0.1571, Accr:96.84
# Epoch [3/7], Step [100/600], Loss: 0.0213, Accr:97.49
# Epoch [3/7], Step [200/600], Loss: 0.0666, Accr:97.51
# Epoch [3/7], Step [300/600], Loss: 0.0403, Accr:98.00
# Epoch [3/7], Step [400/600], Loss: 0.1444, Accr:97.22
# Epoch [3/7], Step [500/600], Loss: 0.0136, Accr:97.61
# Epoch [3/7], Step [600/600], Loss: 0.0668, Accr:97.77
# Epoch [4/7], Step [100/600], Loss: 0.1081, Accr:97.83
# Epoch [4/7], Step [200/600], Loss: 0.0882, Accr:97.57
# Epoch [4/7], Step [300/600], Loss: 0.0823, Accr:98.05
# Epoch [4/7], Step [400/600], Loss: 0.0335, Accr:98.19
# Epoch [4/7], Step [500/600], Loss: 0.1481, Accr:97.88
# Epoch [4/7], Step [600/600], Loss: 0.0281, Accr:98.06
# Epoch [5/7], Step [100/600], Loss: 0.0195, Accr:98.19
# Epoch [5/7], Step [200/600], Loss: 0.0617, Accr:98.01
# Epoch [5/7], Step [300/600], Loss: 0.0231, Accr:98.17
# Epoch [5/7], Step [400/600], Loss: 0.0824, Accr:97.46
# Epoch [5/7], Step [500/600], Loss: 0.0882, Accr:97.78
# Epoch [5/7], Step [600/600], Loss: 0.0842, Accr:97.97
# Epoch [6/7], Step [100/600], Loss: 0.0145, Accr:97.94
# Epoch [6/7], Step [200/600], Loss: 0.0458, Accr:97.28
# Epoch [6/7], Step [300/600], Loss: 0.0725, Accr:97.62
# Epoch [6/7], Step [400/600], Loss: 0.2337, Accr:97.92
# Epoch [6/7], Step [500/600], Loss: 0.0727, Accr:97.41
# Epoch [6/7], Step [600/600], Loss: 0.0714, Accr:97.79
# Epoch [7/7], Step [100/600], Loss: 0.0828, Accr:97.69
# Epoch [7/7], Step [200/600], Loss: 0.0147, Accr:97.71
# Epoch [7/7], Step [300/600], Loss: 0.0575, Accr:98.09
# Epoch [7/7], Step [400/600], Loss: 0.0204, Accr:98.05
# Epoch [7/7], Step [500/600], Loss: 0.0855, Accr:97.75
# Epoch [7/7], Step [600/600], Loss: 0.0286, Accr:97.96

# %% [markdown]
# # 7. 테스트

# %%
print("Accuracy of Test Data: %.2f" %ComputeAccr(test_loader, model))
# Out:
# Accuracy of Test Data: 97.96

# %% [markdown]
# # 8. 학습된 파라미터 저장

# %%
netname='./nets/rnn_weight.pkl'
torch.save(model, netname,)

# %% [markdown]
# # 9. 학습된 파라미터 로드
# - 만약에 바로 로드: 5,6,8 생략

# %%
netname='./nets/rnn_weight.pkl'
model=torch.load(netname)

# %%
print("Accuracy of Test Data: %.2f" %ComputeAccr(test_loader, model))
# Out:
# Accuracy of Test Data: 97.96
